# %%
import pandas as pd
import numpy as np

# %%
dr = pd.read_csv('2021.03.19_results.csv')

# %% [markdown]
# #### Pozbycie się pytań

# %%
index_names_1 = dr[ dr['isQuestion'] == True].index 
dr.drop(index_names_1, inplace = True)
pd.unique(dr['isQuestion'])
# Out:
# array([False])

# %% [markdown]
# #### Pozbycie się nie-regulacji (miękkie kryterium)

# %%
list_other =['Report','Research','White paper','Strategy','Policy principles','Declaration','International agreement','Observatory','Policy paper','Ethics guidelines','Resolution','Principles','Action programme','Declaration','Guidelines','Action plan','Guidance','Strategy, Report']
for i in list_other:
    dr.drop(dr[dr['documentType']==i].index, inplace=True)
pd.unique(dr['documentType'])
# Out:
# array([nan, 'Self-regulation', 'Regulation', 'Proposal',
#        'Self-regulation, Policy principles',
#        'Declaration, International agreement', 'Legislation', 'Bill',
#        'Code of practice'], dtype=object)

# %% [markdown]
# #### Wprowadzenie trzech wartości modalnych

# %%
conditions=[
    (dr['modal']=='should'),
    (dr['modal']=='shall'),
    (dr['modal']=='could'),
    (dr['modal']=='can' ),
    (dr['modal']=='may'),
    (dr['modal']=='might'),
    (dr['modal']=='must')
    ]
values= ['shall', 'shall','can','can','can','can','must']
dr['simple_modal']=np.select(conditions,values)

pd.unique(dr['simple_modal'])
# Out:
# array(['can', 'shall', 'must'], dtype=object)

# %% [markdown]
# #### Tworzenie listy zaimków
# Lista zaimków z https://www.thefreedictionary.com/List-of-pronouns.htm

# %%
with open('eng_pronouns.txt','r') as pro:
    lines_pro=pro.readlines()
list_pro = []
for l in lines_pro:
    list_temp=l.split(', ')
    list_pro.append(list_temp[0].replace('\n',''))
list_pro_c= [e.capitalize() for e in list_pro]

# %% [markdown]
# #### Usuwanie zaimków z 'subject' i 'passiveSubject'.

# %%
for i in list_pro:
    dr.drop(dr[dr['subject']==i].index, inplace=True)
for i in list_pro_c:
    dr.drop(dr[dr['subject']==i].index, inplace=True)
for i in list_pro:
    dr.drop(dr[dr['passiveSubject']==i].index, inplace=True)
for i in list_pro_c:
    dr.drop(dr[dr['passiveSubject']==i].index, inplace=True)

# %% [markdown]
# #### Patrzymy co zostało

# %%
dr_2=dr[dr['documentType']=='Self-regulation']
list(pd.unique(dr_2['subject']))
# Out:
# ['algorithms',
#  nan,
#  'Decisions',
#  'algorithm',
#  'cost',
#  'input',
#  'systems',
#  'use',
#  'Policymakers',
#  'institutions',
#  'Owners',
#  'biases',
#  'Regulators',
#  'concerns',
#  'Institutions',
#  'Innovation',
#  'training',
#  'Zealand',
#  'AI',
#  'adoption',
#  'policies',
#  'Government',
#  'machine',
#  'lack',
#  'definitions',
#  'interfaces',
#  'person',
#  'people',
#  'law',
#  'investment',
#  'May',
#  'House',
#  'software',
#  'result',
#  'strategy',
#  'testing',
#  'sector',
#  'sectors',
#  'same',
#  'introduction',
#  'ability',
#  'Tasks',
#  'businesses',
#  'conversation',
#  'Teachers',
#  'Amy',
#  'application',
#  'employees',
#  'data',
#  'system',
#  'kind',
#  'People',
#  'Companies',
#  'client',
#  'recovery',
#  'owners',
#  'products',
#  'university',
#  'countries',
#  'regulation',
#  'rules',
#  'transparency',
#  'Customers',
#  'program',
#  'debate',
#  'view',
#  'issue',
#  'farmers',
#  'makers',
#  'investments',
#  'role',
#  'Forum',
#  'compositions',
#  'SMEs',
#  'Agencies',
#  'Organisations',
#  'scale',
#  'qualifications',
#  'curriculum',
#  'group',
#  'review',
#  'companies',
#  'robots',
#  'platforms',
#  'machines',
#  'Manufacturers',
#  'Faults',
#  'Errors',
#  'errors',
#  'types',
#  'man',
#  'Robots',
#  'robot',
#  'factors',
#  'Bias',
#  'programmers',
#  'bias',
#  'experts',
#  'researchers',
#  'studies',
#  'work',
#  'manufacturers',
#  'principle',
#  'Machines',
#  'learning',
#  'incident',
#  'designers',
#  'actions',
#  'decisions',
#  'version',
#  'verifications',
#  'participants',
#  'requirement',
#  'option',
#  'participant',
#  'issues',
#  'applications',
#  'gies',
#  'society',
#  'technology',
#  'sation',
#  'technologies',
#  'citizens',
#  'laws',
#  'innovation',
#  'design',
#  'processing',
#  'parties',
#  'ard',
#  'contributions',
#  'Interests',
#  'Potential',
#  'party',
#  'author-',
#  'requirements',
#  'assessments',
#  'expansion',
#  'operators',
#  'schemes',
#  'services',
#  'obligations',
#  'stakeholders',
#  'stage',
#  'duties',
#  'efforts',
#  'balance',
#  'State',
#  'individuals',
#  'process',
#  'users',
#  'severity',
#  'legislator',
#  'instruments',
#  'ed',
#  'instrument',
#  'risks',
#  'individual',
#  'measures',
#  'objective',
#  'consideration',
#  'assessment',
#  'criteria',
#  'influence',
#  'centre',
#  'evidence',
#  'rights',
#  'latter',
#  'human',
#  'measure',
#  'provisions',
#  'operator',
#  'bank',
#  'changes',
#  'and/',
#  'regime',
#  'alone',
#  'Opinion',
#  'ethics',
#  'feature']

# %%
dr_2=dr[dr['documentType']=='Self-regulation']
list(pd.unique(dr_2['passiveSubject']))
# Out:
# [nan,
#  'outputs',
#  'models',
#  'principles',
#  'Institutions',
#  'description',
#  'Auditability',
#  'graphs',
#  'question',
#  'AI',
#  'importance',
#  'issues',
#  'technology',
#  'progress',
#  'Data',
#  'development',
#  'systems',
#  'networks',
#  'roles',
#  'Bias',
#  'tool',
#  'process',
#  'treaty',
#  'robots',
#  'discussion',
#  'driver',
#  'approach',
#  'group',
#  'Benefits',
#  'amounts',
#  'investment',
#  'structure',
#  'Consideration',
#  'researchers',
#  'focus',
#  'Narratives',
#  'groups',
#  'programme',
#  'Government',
#  'initiative',
#  'potential',
#  'labour',
#  'impact',
#  'occupation',
#  'information',
#  'levels',
#  'requirements',
#  'machine',
#  'assessment',
#  'machines',
#  'robot',
#  'types',
#  'Efforts',
#  'system',
#  'responsibility',
#  'interface',
#  '•',
#  'steps',
#  'datasets',
#  'use',
#  'decisions',
#  'the',
#  'forms',
#  'processes',
#  'registration',
#  'Details',
#  'conformity',
#  'product',
#  'approval',
#  'stage',
#  'majority',
#  'attempts',
#  'version',
#  'dimension',
#  'humans',
#  'term',
#  'Ethics',
#  'perspectives',
#  'Controllers',
#  'governance',
#  'lations',
#  'rights',
#  'data',
#  'individual',
#  'factors',
#  'Attempts',
#  'consideration',
#  'consumers',
#  'range',
#  'concerns',
#  'attention',
#  'Standards',
#  'number',
#  'icons',
#  'Action',
#  'manufacturers',
#  'companies',
#  'ability',
#  'action',
#  'regulations',
#  'guidelines',
#  'efforts',
#  'measures',
#  'funding',
#  'research',
#  'method',
#  'codes',
#  'effects',
#  'priority',
#  'level',
#  'concepts',
#  'Provision',
#  'Systems',
#  'help',
#  'Questions',
#  'scheme',
#  'introduction',
#  'pool',
#  'ban',
#  'operators',
#  'right',
#  'society',
#  'members',
#  'work',
#  'sets',
#  'criteria',
#  'tasks',
#  'commission',
#  'ment',
#  'Communications',
#  'panies',
#  'options',
#  'gamut',
#  'thorities',
#  'scope',
#  'care',
#  'rules']

# %%
dr_2=dr[dr['documentType']=='Regulation']
list(pd.unique(dr_2['subject']))
# Out:
# [nan,
#  'evolution',
#  'technologies',
#  'vehicles',
#  'technology',
#  'approach',
#  'vehicle',
#  'developers',
#  'public',
#  'Governments',
#  'partners',
#  'oversight',
#  'preemption',
#  'interior',
#  'NHTSA',
#  'ADS',
#  'standards',
#  'Standards',
#  'condition',
#  'carrier',
#  'equipment',
#  'requirements',
#  'qualifications',
#  'carriers',
#  'Carriers',
#  'Entities',
#  'driver',
#  'agencies',
#  'incentives',
#  'operations',
#  'lack',
#  'facilities',
#  'automation',
#  'ports',
#  'FHWA',
#  'Department',
#  'roles',
#  'governments',
#  'States',
#  'legislatures',
#  'use',
#  'assessments',
#  'interaction',
#  'Testing',
#  'exchange',
#  'policymakers',
#  'Agencies',
#  'operators',
#  'implementation',
#  'Integration',
#  'example',
#  'industry',
#  'institutions',
#  'FTA',
#  'L',
#  'demonstrations',
#  'transfer',
#  'environment',
#  'users',
#  'engagement',
#  'investments',
#  'makers',
#  'Plans',
#  'threat',
#  'E',
#  'sector',
#  'companies',
#  'entities',
#  'capability',
#  'personnel',
#  'functionality',
#  'system',
#  'OEMs',
#  'Government',
#  'consumers',
#  'dealers',
#  'members',
#  'risks',
#  'exchanges',
#  'information',
#  'Industry',
#  'laws',
#  'officers',
#  'developer',
#  'software',
#  'cases',
#  'items',
#  'changes',
#  'environments',
#  'entity',
#  'assessment',
#  'actions',
#  'drivers',
#  'framework',
#  'DOT',
#  'car',
#  'innovation',
#  'introduction',
#  'transition',
#  'term',
#  'Secretary',
#  'user',
#  'trip',
#  'documents',
#  'infrastructure',
#  'needs',
#  'defect',
#  'activity',
#  'development',
#  'innovations',
#  'HAV',
#  'inclusion',
#  'HAVs',
#  'manufacturers',
#  'motorist',
#  'integration',
#  'manufacturer',
#  'tools',
#  'Level',
#  'Manufacturers',
#  'Agency',
#  'Assessment',
#  'submitter',
#  'platforms',
#  'competencies',
#  'Recording',
#  'Vehicles',
#  'data',
#  'ers',
#  'Safety',
#  'process',
#  'testing',
#  'considerations',
#  'Cybersecurity',
#  'mented',
#  'design',
#  'indicators',
#  'authority',
#  'Examples',
#  'compatibility',
#  'education',
#  'owner',
#  'Behavior',
#  'Laws',
#  'outcomes',
#  'programming',
#  'achievement',
#  'resolution',
#  'ODD',
#  'instructions',
#  'Events',
#  'strategies',
#  'functions',
#  'Tests',
#  'approaches',
#  'systems',
#  'distinction',
#  'expectations',
#  'standard',
#  'State',
#  'areas',
#  'aspect',
#  'aim',
#  'agency',
#  'jurisdiction',
#  'application',
#  'and/or',
#  'activities',
#  'Regulations',
#  'hazards',
#  'Rules',
#  'rules',
#  'letters',
#  'interpretation',
#  'compliance',
#  'petition',
#  'Parties',
#  'requestors',
#  'Counsel',
#  'letter',
#  'person',
#  'facts',
#  'situation',
#  'factors',
#  'Requestors',
#  'question',
#  'requestor',
#  'parties',
#  'exemption',
#  'statement',
#  'petitions',
#  'processes',
#  'ones',
#  'number',
#  'capabilities',
#  'program',
#  'combination',
#  'absence',
#  'version',
#  'features',
#  'statute',
#  'exemptions',
#  'updates',
#  'tests',
#  'amendment',
#  'protocols',
#  'detail',
#  'result',
#  'stakeholders',
#  'incident',
#  'Petitions',
#  'types',
#  'man-',
#  'regulations',
#  'retary',
#  'models',
#  'banks',
#  'Details',
#  'steps',
#  'risk',
#  'model',
#  'Errors',
#  'problems',
#  'events',
#  'Banks',
#  'challenge',
#  'adjustments',
#  'management',
#  'bank',
#  'Developers',
#  'practices',
#  'calculations',
#  'questioning',
#  'reports',
#  'Reports',
#  'Accounting',
#  'aspects',
#  'assumptions',
#  'conservatism',
#  'components',
#  'rigor',
#  'Staff',
#  'staff',
#  'report',
#  'fact',
#  'uncertainty',
#  'estimates',
#  'determination',
#  'Validation',
#  'validation',
#  'Documentation',
#  'Management',
#  'code',
#  'analysis',
#  'monitoring',
#  'source',
#  'Discrepancies',
#  'results',
#  'prediction',
#  'nature',
#  'Analysis',
#  'Models',
#  'Outcomes',
#  'Adjustments',
#  'Vendors',
#  'customization',
#  'relevance',
#  'board',
#  'policies',
#  'Policies',
#  'owners',
#  'Issues',
#  'Compliance',
#  'function',
#  'audit',
#  'resources',
#  'party',
#  'line',
#  'inventory',
#  'input',
#  'robots',
#  'robotics',
#  'devices',
#  'Canada',
#  'context',
#  'concept',
#  'losses',
#  'issue',
#  'partnership',
#  'government',
#  'workforce',
#  'surgeon',
#  'sponsor',
#  'regulator',
#  'Conference',
#  'groups',
#  'Infoway',
#  'CADTH',
#  'programs',
#  'platform',
#  'safety',
#  'ADSs',
#  'Thorough',
#  'pedestrians',
#  'operating',
#  'extent',
#  'scenarios',
#  'prerequisites',
#  'Inclusion',
#  'ability',
#  'collection']

# %%
dr_2=dr[dr['documentType']=='Regulation']
list(pd.unique(dr_2['passiveSubject']))
# Out:
# [nan,
#  'potential',
#  'risks',
#  'vehicles',
#  'vehicle',
#  'Standards',
#  'procedures',
#  'regulations',
#  'vulnerabilities',
#  'assistance',
#  'information',
#  'technologies',
#  'CMVs',
#  'Implementation',
#  'fines',
#  'entities',
#  'approaches',
#  'spectrum',
#  'trust',
#  'stage',
#  'hardware',
#  'testing',
#  'encounters',
#  'public',
#  'features',
#  'interests',
#  'needs',
#  'communications',
#  'Boundaries',
#  'rules',
#  'percent',
#  'capacity',
#  'data',
#  'way',
#  'Examples',
#  'Guidance',
#  'tests',
#  'process',
#  'change',
#  'Data',
#  'motor',
#  'circumstances',
#  'decisions',
#  'identification',
#  'Considerations',
#  'programs',
#  'software',
#  'HAV',
#  'objectives',
#  'conflict',
#  'safety',
#  'Algorithms',
#  'ODD',
#  'actions',
#  'Testing',
#  'systems',
#  'robustness',
#  'mechanisms',
#  'standards',
#  'laws',
#  'stakeholders',
#  'Approval',
#  'authorization',
#  'permit',
#  'training',
#  'persons',
#  'crashes',
#  'gaps',
#  'Vehicles',
#  'agency',
#  'registration',
#  'Regulations',
#  'Responders',
#  'questions',
#  'Questions',
#  'exemptions',
#  'exemption',
#  'description',
#  'absence',
#  'variety',
#  '•',
#  'approach',
#  'NHTSA',
#  'Agency',
#  'simulation',
#  'reporting',
#  'provisions',
#  'need',
#  'agreements',
#  'Safeguards',
#  'Petitions',
#  'proposal',
#  'reasons',
#  'petitioner',
#  'text',
#  'Level',
#  'Much',
#  'consequences',
#  'meeting',
#  'quality',
#  'model',
#  'risk',
#  'tools',
#  'Models',
#  'factors',
#  'values',
#  'inputs',
#  'nature',
#  'sensitivity',
#  'validation',
#  'independence',
#  'work',
#  'level',
#  'influence',
#  'Influence',
#  'use',
#  'models',
#  'evidence',
#  'assumptions',
#  'relevance',
#  'changes',
#  'Reports',
#  'sources',
#  'choice',
#  'Tests',
#  'attention',
#  'appropriateness',
#  'scrutiny',
#  'framework',
#  'management',
#  'prioritization',
#  'roles',
#  'responsibilities',
#  'resources',
#  'Findings',
#  'Accuracy',
#  'processes',
#  'benefit',
#  'variation',
#  'report',
#  'services',
#  'robots',
#  'medicine',
#  'tissue',
#  'type',
#  'effect',
#  'youth',
#  'number',
#  'Conferences',
#  'innovation',
#  'entity',
#  'ADS',
#  'drivers',
#  'forms',
#  'Parts',
#  'consumers']

# %%
dr_2=dr[dr['documentType']=='Proposal']
list(pd.unique(dr_2['subject']))
# Out:
# [nan,
#  'strategy',
#  'investments',
#  'development',
#  'Mexico',
#  'AI',
#  'areas',
#  'Economies',
#  'Government',
#  'Data',
#  'uses',
#  'adoption',
#  'Centre',
#  'centre',
#  'implementation',
#  'person',
#  'companies',
#  'observations',
#  'cutting',
#  'department',
#  'Office',
#  'government',
#  'Conacyt',
#  'Research',
#  'sandbox',
#  'fund',
#  'quality',
#  'Strategy',
#  'sets',
#  'Protection',
#  'industry',
#  'Agencies',
#  'Governments',
#  'turn',
#  'systems',
#  'AIAs',
#  'process',
#  'agencies',
#  'officials',
#  'harms',
#  'Assessment',
#  'disclosures',
#  'requests',
#  'Impact',
#  'access,29',
#  'agency',
#  'public',
#  'definition',
#  'input',
#  'text',
#  'wording',
#  'Schools',
#  'language',
#  'value',
#  'scenarios',
#  'system',
#  'researchers',
#  'assessment',
#  'individuals',
#  'processes',
#  'incentives',
#  'experts',
#  'Researchers',
#  'staff',
#  'Assessments',
#  'plan',
#  'type',
#  'risks',
#  'right',
#  'tools',
#  'legislation',
#  'framework',
#  'jurisdictions',
#  'work',
#  'judgements',
#  'cases',
#  'algorithms',
#  'things',
#  'much',
#  'Authority',
#  'MIC']

# %%
dr_2=dr[dr['documentType']=='Proposal']
list(pd.unique(dr_2['passiveSubject']))
# Out:
# ['benefits',
#  'investments',
#  nan,
#  'guidelines',
#  'AI',
#  'measures',
#  'production',
#  'skilling',
#  'methodology',
#  'model',
#  'products',
#  'problems',
#  'approach',
#  'children',
#  'law',
#  'disclosures',
#  'agency',
#  'agencies',
#  'Agencies',
#  'rights',
#  'public',
#  'research',
#  'vendors',
#  'evaluation',
#  'Data',
#  'issues',
#  'accountability',
#  'boards',
#  'Funding',
#  'trust',
#  'industries',
#  'view',
#  'description',
#  'Lessons']

# %%
dr_2=dr[dr['documentType']=='Self-regulation, Policy principles']
list(pd.unique(dr_2['subject']))
# Out:
# ['AI',
#  'industry',
#  'researchers',
#  nan,
#  'Failure',
#  'machines',
#  'transformations',
#  'agents',
#  'technologies',
#  'development',
#  'overregulating',
#  'governments',
#  'users',
#  'systems',
#  'sectors']

# %%
dr_2=dr[dr['documentType']=='Self-regulation, Policy principles']
list(pd.unique(dr_2['passiveSubject']))
# Out:
# [nan, 'solutions', 'systems', 'approach', 'portion']

# %%
dr_2=dr[dr['documentType']=='Declaration, International agreement']
list(pd.unique(dr_2['subject']))
# Out:
# ['signatories']

# %%
dr_2=dr[dr['documentType']=='Declaration, International agreement']
list(pd.unique(dr_2['passiveSubject']))
# Out:
# [nan]

# %%
dr_2=dr[dr['documentType']=='Legislation']
list(pd.unique(dr_2['subject']))
# Out:
# ['States',
#  'safety',
#  nan,
#  'driver',
#  'ADSs',
#  'features',
#  'process',
#  'Thorough',
#  'considerations',
#  'actions',
#  'ODD',
#  'ADS',
#  'vehicle',
#  'condition',
#  'system',
#  'pedestrians',
#  'operating',
#  'strategies',
#  'drivers',
#  'Tests',
#  'approaches',
#  'extent',
#  'Entities',
#  'design',
#  'Examples',
#  'vehicles',
#  'scenarios',
#  'Behavior',
#  'entities',
#  'Vehicles',
#  'data',
#  'programs',
#  'staff',
#  'dealers',
#  'development',
#  'entity',
#  'information',
#  'Assessment',
#  'aim',
#  'areas',
#  'State',
#  'manufacturers',
#  'prerequisites',
#  'agency',
#  'governments',
#  'Inclusion',
#  'ability',
#  'operators',
#  'determination',
#  'updates',
#  'NHTSA',
#  'collection']

# %%
dr_2=dr[dr['documentType']=='Legislation']
list(pd.unique(dr_2['passiveSubject']))
# Out:
# [nan,
#  'entity',
#  'decisions',
#  'ADS',
#  'Testing',
#  'drivers',
#  'Considerations',
#  'information',
#  'actions',
#  'Data',
#  'circumstances',
#  'approaches',
#  'programs',
#  'process',
#  'forms',
#  'Parts',
#  'consumers']

# %%
dr_2=dr[dr['documentType']=='Bill']
list(pd.unique(dr_2['subject']))
# Out:
# ['person', nan, 'court', 'A', 'i']

# %%
dr_2=dr[dr['documentType']=='Bill']
list(pd.unique(dr_2['passiveSubject']))
# Out:
# [nan, 'violation', 'subsection']

# %%
dr_2=dr[dr['documentType']=='Code of practice']
list(pd.unique(dr_2['subject']))
# Out:
# [nan,
#  'Testing',
#  'businesses',
#  'vehicle',
#  'vehicles',
#  'organisations',
#  'public',
#  'operator',
#  'Testers',
#  'person',
#  'operators',
#  'organisation',
#  'drivers',
#  'Training',
#  'Organisations',
#  'data',
#  'test',
#  'Vehicle']

# %%
dr_2=dr[dr['documentType']=='Code of practice']
list(pd.unique(dr_2['passiveSubject']))
# Out:
# [nan,
#  'code',
#  'definitions',
#  'person',
#  'requirements',
#  'consideration',
#  'availability',
#  'vehicles',
#  'vehicle',
#  'facilities',
#  'data',
#  'individuals',
#  'Guidance',
#  'assessment',
#  'hardware']

# %% [markdown]
# Co trzeb zrobić:
#     + wyrzucić nie-regulacje; DONE!
#     + wyrzucić zaimki i przydawki z podmiotów (wszystkich klas podmiotów); DONE!
#     + zobaczyć jakie zestawy (podmiot; deontic; orzeczenie);
#         - strona czynna -> jakiego aktora działanie jest regulowane;
#         - strona bierna -> działanie wobec jakiego obiektu jest regulowane;
#     + skrosować to z krajami; typami regulacji.
