# %%
import pandas as pd
import numpy as np

# %%
dr = pd.read_csv('2021.03.19_results.csv')

# %%
list(dr.columns)
# Out:
# ['Unnamed: 0',
#  'modal',
#  'sent',
#  'doc_id',
#  'verb',
#  'subject',
#  'passiveSubject',
#  'clausalSubject',
#  'token',
#  'isQuestion',
#  'id',
#  'nestaId',
#  'title',
#  'country',
#  'documentUrl',
#  'year',
#  'category',
#  'documentType',
#  'actors',
#  'description',
#  'startDate',
#  'endDate',
#  'oecdId']

# %%
dr.head()
# Out:
#    Unnamed: 0   modal                                               sent  \
# 0           0     may  The full recordings of the conference may be v...
# 1           1   could  The majority viewed the concept of artificial ...
# 2           2   could  Based on the majority view that AGI has not ye...
# 3           3     may  However, some  commenters stressed that it may...
# 4           4  should  Most public commenters agreed that the growing...
#
#                            doc_id    verb subject passiveSubject  \
# 0  data/oecd_docs/texts/24914.txt  viewed     NaN     recordings
# 1  data/oecd_docs/texts/24914.txt   arise    that            NaN
# 2  data/oecd_docs/texts/24914.txt  invent      AI            NaN
# 3  data/oecd_docs/texts/24914.txt      be      it            NaN
# 4  data/oecd_docs/texts/24914.txt   issue   right            NaN
#
#   clausalSubject   token  isQuestion  ... country  \
# 0            NaN     may       False  ...   Italy
# ...

# %%
list(dr.sample(n=10)['doc_id'])
# Out:
# ['data/oecd_docs/texts/24953.txt',
#  'data/oecd_docs/texts/26781.txt',
#  'data/nesta_ai_governance_docs/texts/opinion-of-the-german-data-ethics-commission.txt',
#  'data/nesta_ai_governance_docs/texts/new-york-city-automated-decision-systems-task-force-report.txt',
#  'data/oecd_docs/texts/26832.txt',
#  'data/oecd_docs/texts/24953.txt',
#  'data/nesta_ai_governance_docs/texts/austrian-action-programme-on-automated-mobility-2019-2022.txt',
#  'data/oecd_docs/texts/26088.txt',
#  'data/nesta_ai_governance_docs/texts/bigdata-discrimination-in-data-supported-decision-making.txt',
#  'data/nesta_ai_governance_docs/texts/algorithms-in-decisionmaking.txt']
